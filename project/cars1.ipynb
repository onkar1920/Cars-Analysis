# %% [markdown]
# ### CARS DATASET
#
# HERE THE DATA OF DIFFERENT CARS IS GIVEN WITH THEIR SPECIFICATION
# THIS DATA IS AVAILABLE AS CSV FILE.
# WE ARE GOING TO ANALYSE THIS DATA SET USING PANDAS DATA FRAME,, NUMPY, MATPLOTLIB AND SEABORN.

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### READING & CLEANING OF DATA AND FORMATTING IT PROPERLY

# %%
data = pd.read_csv("carsdata.csv")

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 351  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 352  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 353  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 354  Volvo                      V40  Wagon  Europe      Front  $26,135
# 355  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data.rename(columns={'Make':"Brand"},inplace=True) #renaming done of (make) to Brand

# %%
data.head()
# Out:
#    Brand           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %% [markdown]
# ### FIND ALL THE NULL VALUES IN DATASET. IF THERE IS ANY NULL VALUE IN ANY COLUMN THEN FILL IT WITH THE MEAN OF THAT COLUMN

# %%
data.isnull().sum()
# Out:
# Brand          0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
data['Cylinders'].fillna(data['Cylinders'].mean(), inplace = True)
data
# Out:
#      Brand                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 351  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 352  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 353  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 354  Volvo                      V40  Wagon  Europe      Front  $26,135
# 355  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### INFORMATION OF THE FILE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        356 non-null    object
#  1   Model        356 non-null    object
#  2   Type         356 non-null    object
#  3   Origin       356 non-null    object
#  4   DriveTrain   356 non-null    object
#  5   MSRP         356 non-null    object
#  6   Invoice      356 non-null    object
#  7   EngineSize   356 non-null    float64
#  8   Cylinders    356 non-null    float64
#  9   Horsepower   356 non-null    int64
#  10  MPG_City     356 non-null    int64
#  11  MPG_Highway  356 non-null    int64
#  12  Weight       356 non-null    int64
#  13  Wheelbase    356 non-null    int64
#  14  Length       356 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 41.8+ KB

# %% [markdown]
# ### DESCRIPTION OF FILE

# %%
data.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  356.000000  356.000000  356.000000  356.000000   356.000000
# mean     3.216011    5.807910  216.441011   19.839888    26.609551
# std      1.104177    1.559106   70.886137    4.767222     5.355720
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.825000    6.000000  255.000000   21.000000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   356.000000  356.000000  356.000000
# mean   3592.325843  108.339888  187.106742
# std     724.727174    8.393471   14.180918
# min    1850.000000   89.000000  143.000000
# 25%    3128.000000  103.000000  178.000000
# 50%    3491.500000  107.000000  187.000000
# 75%    3981.000000  112.250000  194.000000
# ...

# %% [markdown]
# ### CHECK WHAT ARE THE DIFFERENT TYPE OF BRAND ARE THERE PRESENT IN OUR DATASET.AND WHAT IS THE COUNT (OCCURRENCE) OF EACH BRAND IN DATA?

# %%
data.value_counts("Brand")
# Out:
# Brand
# Nissan           17
# Honda            17
# Mercedes-Benz    16
# Volkswagen       15
# Chrysler         15
# Toyota           13
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Ford             12
# Hyundai          12
# Jaguar           12
# Kia              11
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Chevrolet        11
# Audi             10
# Lincoln           9
# BMW               9
# Buick             9
# Mercury           9
# Saturn            8
# Infiniti          8
# Suzuki            8
# GMC               8
# Cadillac          8
# Acura             7
# Porsche           7
# Saab              7
# Jeep              3
# Land Rover        3
# Oldsmobile        3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# dtype: int64

# %% [markdown]
# ### FINDING THE TOTAL COUNT OF BRAND | WHICH BRAND HAS MORE DEMAND IN RESALE MARKET

# %%
plt.figure(figsize=(19,19))
data['Brand'].value_counts().plot(kind='bar')
plt.title("MODEL")
plt.ylabel("NO of model")
plt.xlabel("BRAND")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### TOTAL NUMBER OF CAR IN LIST WITH CAR MODEL

# %%
plt.figure(figsize=(10,10))
data['Model'].value_counts().nlargest(10).plot(kind='barh') # pandas plot as there is a lot of data so i took the .nlargest function
plt.title("Car Brand")
plt.ylabel("Brand")
plt.xlabel("count")
plt.xticks(rotation=90)
plt.show()

# %%
data.value_counts("Model")
# Out:
# Model
# G35 4dr                    2
# 3.5 RL 4dr                 1
# Q45 Luxury 4dr             1
# Ram 1500 Regular Cab ST    1
# Rainier                    1
#                           ..
# Escalade                   1
# Envoy XUV SLE              1
# Endeavor XLS               1
# Element LX                 1
# xB                         1
# Length: 355, dtype: int64

# %% [markdown]
# ### MAXIMUM COUNT OF THE CAR MODEL

# %%
data.value_counts("Model").idxmax()
# Out:
# 'G35 4dr'

# %% [markdown]
# ### MINIMUM COUNT OF THE CAR MODEL

# %%
data.value_counts("Model").idxmin()
# Out:
# '3.5 RL 4dr'

# %% [markdown]
# ### TOTAL NUMBER OF CAR IN LIST WITH CAR TYPE

# %%
plt.figure(figsize=(10,10))
data['Type'].value_counts().plot(kind="barh") # pandas plot
plt.title("Car Brand")
plt.ylabel("Brand")
plt.xlabel("count")
plt.xticks(rotation=90)
plt.show()

# %%
data.value_counts("Type")
# Out:
# Type
# Sedan     217
# SUV        45
# Sports     41
# Wagon      27
# Truck      24
# Hybrid      2
# dtype: int64

# %% [markdown]
# ### MAXIMUM COUNT OF THE CAR TYPE

# %%
data.value_counts("Type").idxmax()
# Out:
# 'Sedan'

# %% [markdown]
# ### MINIMUM COUNT OF THE CAR TYPE

# %%
data.value_counts("Type").idxmin()
# Out:
# 'Hybrid'

# %% [markdown]
# ### NOW WE WILL SEE THE ORIGIN ON PIECHART

# %%
#seeing origin in market
plt.figure(figsize=(9,9))
data["Origin"].value_counts().plot.pie(autopct="%1.2f%%")
plt.title("Origin")
plt.show()

# %%
#in this scenario we are using seaborn
sns.set(style="darkgrid")
a=sns.countplot(x = "Origin", data = data)

# %% [markdown]
# ### CARS IN ORIGIN(CONTINENT)
# SHOW ALL THE RECORDS WHERE ORIGIN IS ASIA OR Europe

# %%
data[data['Origin'].isin(['Asia', 'Europe'])]
# Out:
#      Brand                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 351  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 352  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 353  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 354  Volvo                      V40  Wagon  Europe      Front  $26,135
# 355  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data["Origin"].value_counts()
# Out:
# Asia      143
# USA       120
# Europe     93
# Name: Origin, dtype: int64

# %% [markdown]
# ### MAXIMUM COUNT OF ORIGIN

# %%
data.value_counts("Origin").idxmax()
# Out:
# 'Asia'

# %%
Origin= data[data['Origin'] == 'Asia'].sort_values(by ='MSRP') #hunting for top orgin and sorting MSRP(Maximum Sales Retail Price)
Origin
# Out:
#         Brand                   Model    Type Origin DriveTrain      MSRP  \
# 159       Kia          Rio 4dr manual   Sedan   Asia      Front  $10,280
# 121   Hyundai        Accent 2dr hatch   Sedan   Asia      Front  $10,539
# 160       Kia            Rio 4dr auto   Sedan   Asia      Front  $11,155
# 122   Hyundai           Accent GL 4dr   Sedan   Asia      Front  $11,839
# 167       Kia               Rio Cinco   Wagon   Asia      Front  $11,905
# ..        ...                     ...     ...    ...        ...       ...
# 137  Infiniti          Q45 Luxury 4dr   Sedan   Asia       Rear  $52,545
# 179     Lexus              LS 430 4dr   Sedan   Asia       Rear  $55,750
# 180     Lexus  SC 430 convertible 2dr  Sports   Asia       Rear  $63,200
# 172     Lexus                  LX 470     SUV   Asia        All  $64,800
# 6       Acura  NSX coupe 2dr manual S  Sports   Asia       Rear  $89,765
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
plt.figure(figsize=(9,9)) #chart give view of origin with number of cars
sns.countplot(data=data, x="Origin")
plt.show()

# %%
group=data.groupby(["Origin","Brand"]).sum() #showing origin and their car details
group
# Out:
#                       EngineSize   Cylinders  Horsepower  MPG_City  \
# Origin Brand
# Asia   Acura                21.3   38.000000        1675       136
#        Honda                40.5   77.000000        2880       473
#        Hyundai              28.6   60.000000        1796       276
#        Infiniti             31.0   54.000000        2330       138
#        Isuzu                 7.4   12.000000         468        32
#        Kia                  25.8   52.000000        1574       241
#        Lexus                40.9   76.000000        2680       192
#        Mazda                24.1   51.615819        1867       236
#        Mitsubishi           36.1   64.000000        2396       272
#        Nissan               57.9   98.000000        3876       335
#        Scion                 3.0    8.000000         216        63
#        Subaru               28.0   48.000000        2106       223
#        Suzuki               18.6   38.000000        1208       177
# ...

# %% [markdown]
# ### REMOVE ALL THE RECRDS(ROW) WHERE WEIGHT IS ABOVE 4000

# %%
data[~(data['Weight'] > 4000 )]
# Out:
#      Brand                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 351  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 352  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 353  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 354  Volvo                      V40  Wagon  Europe      Front  $26,135
# 355  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### FINDING THE CORRELATION

# %%
corr=data.corr()
corr
# Out:
#              EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# EngineSize     1.000000   0.895740    0.786413 -0.713388    -0.697299
# Cylinders      0.895740   1.000000    0.807422 -0.691730    -0.653018
# Horsepower     0.786413   0.807422    1.000000 -0.675629    -0.622252
# MPG_City      -0.713388  -0.691730   -0.675629  1.000000     0.948467
# MPG_Highway   -0.697299  -0.653018   -0.622252  0.948467     1.000000
# Weight         0.779002   0.714926    0.607717 -0.754800    -0.779385
# Wheelbase      0.603740   0.513818    0.353410 -0.512547    -0.516266
# Length         0.615720   0.531578    0.364475 -0.519346    -0.469669
#
#                Weight  Wheelbase    Length
# EngineSize   0.779002   0.603740  0.615720
# Cylinders    0.714926   0.513818  0.531578
# Horsepower   0.607717   0.353410  0.364475
# MPG_City    -0.754800  -0.512547 -0.519346
# MPG_Highway -0.779385  -0.516266 -0.469669
# Weight       1.000000   0.748822  0.683975
# ...

# %%
data["Horsepower"].value_counts() #overview of horspower of car in list and their count
# Out:
# 200    14
# 210    12
# 220    11
# 240    11
# 170    10
#        ..
# 238     1
# 242     1
# 247     1
# 258     1
# 500     1
# Name: Horsepower, Length: 99, dtype: int64

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ### from above correlation we conclude that there is a -ve correlation between MPG_City and MPG_Highway,i.e they are inversly proportional to each other #+ve correlation between Enginesize and Cylinders

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=data,x=data.Horsepower,y=data.EngineSize)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(30,30))
sns.scatterplot(data=data,x=data.Brand,y=data.EngineSize,hue="Horsepower")
plt.plot()
# Out:
# []

# %% [markdown]
# ### NOW COUNTING CAR ACCORDING TO CYLINDERS

# %%
plt.figure(figsize=(10,10)) #CAR in market according to Cylinders
sns.countplot(data=data,x=data.Cylinders)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='count'>

# %%
df=data[data["Cylinders"]==4.0].sort_values(by="Brand",ascending=False) #car with 4 cylinders
df.head()
# Out:
#           Brand            Model   Type  Origin DriveTrain      MSRP  \
# 354       Volvo              V40  Wagon  Europe      Front  $26,135
# 345       Volvo          S40 4dr  Sedan  Europe      Front  $25,135
# 342  Volkswagen  Passat GLS 1.8T  Wagon  Europe      Front  $24,955
# 341  Volkswagen         Jetta GL  Wagon  Europe      Front  $19,005
# 336  Volkswagen   Passat GLS 4dr  Sedan  Europe      Front  $23,955
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 354  $24,641          1.9        4.0         170        22           29
# 345  $23,701          1.9        4.0         170        22           29
# 342  $22,801          1.8        4.0         170        22           31
# 341  $17,427          2.0        4.0         115        24           30
# 336  $21,898          1.8        4.0         170        22           31
#
#      Weight  Wheelbase  Length
# 354    2822        101     180
# 345    2767        101     178
# ...

# %%
df=data[data["Cylinders"]==4.0].sort_values(by="Brand",ascending=False)
df.tail()
# Out:
#         Brand                   Model   Type  Origin DriveTrain      MSRP  \
# 49  Chevrolet            Colorado Z85  Truck     USA        All  $18,760
# 7        Audi             A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8        Audi  A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 2       Acura                 TSX 4dr  Sedan    Asia      Front  $26,990
# 1       Acura          RSX Type S 2dr  Sedan    Asia      Front  $23,820
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 49  $17,070          2.8        4.0         175        18           23
# 7   $23,508          1.8        4.0         170        22           31
# 8   $32,506          1.8        4.0         170        23           30
# 2   $24,647          2.4        4.0         200        22           29
# 1   $21,761          2.0        4.0         200        24           31
#
#     Weight  Wheelbase  Length
# 49    3623        111     192
# 7     3252        104     179
# ...

# %%
df=data[data["Cylinders"]==8.0].sort_values(by="Brand",ascending=False) #car in market for 8 cylinders
df.head()
# Out:
#           Brand                  Model    Type  Origin DriveTrain      MSRP  \
# 343  Volkswagen              Passat W8   Wagon  Europe      Front  $40,235
# 339  Volkswagen            Phaeton 4dr   Sedan  Europe      Front  $65,000
# 338  Volkswagen  Passat W8 4MOTION 4dr   Sedan  Europe      Front  $39,235
# 273     Porsche              Cayenne S     SUV  Europe        All  $56,665
# 271     Pontiac                GTO 2dr  Sports     USA       Rear  $33,500
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 343  $36,956          4.0        8.0         270        18           25
# 339  $59,912          4.2        8.0         335        16           22
# 338  $36,052          4.0        8.0         270        18           25
# 273  $49,865          4.5        8.0         340        14           18
# 271  $30,710          5.7        8.0         340        16           20
#
#      Weight  Wheelbase  Length
# 343    4067        106     184
# ...

# %% [markdown]
# ### NOW CALCULATING THE PRICE AND WHICH BRAND HAS CAR IN THAT PRICE RANGE

# %%
group=data.groupby(["MSRP","Brand"]).mean() #Car brand at which price available
group
# Out:
#                         EngineSize  Cylinders  Horsepower  MPG_City  \
# MSRP     Brand
# $10,280  Kia                   1.6        4.0       104.0      26.0
# $10,539  Hyundai               1.6        4.0       103.0      29.0
# $10,995  Saturn                2.2        4.0       140.0      26.0
# $11,155  Kia                   1.6        4.0       104.0      25.0
# $11,839  Hyundai               1.6        4.0       103.0      29.0
# ...                            ...        ...         ...       ...
# $86,970  Mercedes-Benz         5.0        8.0       302.0      16.0
# $86,995  Jaguar                4.2        8.0       390.0      16.0
# $89,765  Acura                 3.2        6.0       290.0      17.0
# $90,520  Mercedes-Benz         5.0        8.0       302.0      16.0
# $94,820  Mercedes-Benz         5.0        8.0       302.0      16.0
#
#                         MPG_Highway  Weight  Wheelbase  Length
# MSRP     Brand
# ...

# %% [markdown]
# ### CAR AND ITS LENGTH

# %%
group=data.groupby(["Length","Brand"]).sum()                                 
group
# Out:
#                   EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# Length Brand
# 143    MINI              1.6        4.0         115        28           37
# 144    MINI              1.6        4.0         163        25           34
# 150    Jeep              4.0        6.0         190        16           19
# 153    Toyota            1.8        4.0         138        26           32
# 154    Scion             1.5        4.0         108        32           38
# ...                      ...        ...         ...       ...          ...
# 222    Chevrolet         5.3        8.0         295        14           18
#        GMC               6.0        8.0         300        13           18
# 224    Nissan            5.6        8.0         305        14           18
# 230    GMC               4.8        8.0         285        17           20
# 238    Chevrolet         6.0        8.0         300        13           17
#
#                   Weight  Wheelbase
# Length Brand
# ...

# %% [markdown]
# ### USING PAIR PLOT TO SHOW THE RELATION BETWEEN ALL VARIABLE

# %%
sns.pairplot(data)

# %% [markdown]
# ### CONCLUSION
#
# 1]Brand having more demand in resale market--> Nissan,Honda,Mercedes-Benz,Volkswagen,Chrysler
# 2]car  model with highest count in market--> G35 4dr
# 3]car  type with highest count in market--> Sedan
# 4]Origin in market-->ASIA(40.17%),USA(33.71),Europe(26.12%)
# 5]Car Enginesize to Horsepower relation as enginesize increace the horsepower also increases.
# 6]Cars in market after their production as 4 cylinders they are Volvo,Volkswagen,Chevrolet,Acura,Audi and the 8 cylinders one are Porsce,Pontiac,Volkswagen
# 7]Cars Range = Kia,Hyundai,Saturn starting from MSRP $10200-12000 and Mercedes Benz,Acura,Jaguar starting from $86000-99000
